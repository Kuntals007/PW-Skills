# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv("kidney_disease.csv")

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn  dm  cad appet  pe ane classification
# 395  ...   47  6700  4.9   no  no   no  good  no  no         notckd
# 396  ...   54  7800  6.2   no  no   no  good  no  no         notckd
# 397  ...   49  6600  5.4   no  no   no  good  no  no         notckd
# 398  ...   51  7200  5.9   no  no   no  good  no  no         notckd
# 399  ...   53  6800  6.1   no  no   no  good  no  no         notckd
#
# [5 rows x 26 columns]

# %%
df.drop('id', axis = 1, inplace=True)

# %%
df.head(2)
# Out:
#     age    bp    sg   al   su  rbc      pc         pcc          ba    bgr  \
# 0  48.0  80.0  1.02  1.0  0.0  NaN  normal  notpresent  notpresent  121.0
# 1   7.0  50.0  1.02  4.0  0.0  NaN  normal  notpresent  notpresent    NaN
#
#    ...  pcv    wc   rc  htn   dm cad appet  pe ane classification
# 0  ...   44  7800  5.2  yes  yes  no  good  no  no            ckd
# 1  ...   38  6000  NaN   no   no  no  good  no  no            ckd
#
# [2 rows x 25 columns]

# %%
df.columns = ["Age", "Blood Pressure", "Specific Gravity", "Albumin", "Sugar", "Red Blood Cells", "Pus Cells", "Pus Cell Clumps", "Bacteria", "Blood Glucose Random", "Blood Urea", "Serum Creatinine", "Sodium", "Potassium", "Hemoglobin", "Packed Cell Volume", "White Blood Cell Count", "Red Blood Cell Count", "Hypertension", "Diabetes Mellitus", "Coronary Artery Disease", "Appetite", "Pedal Edema", "Anemia","Classification"]

# %%
df.columns
# Out:
# Index(['Age', 'Blood Pressure', 'Specific Gravity', 'Albumin', 'Sugar',
#        'Red Blood Cells', 'Pus Cells', 'Pus Cell Clumps', 'Bacteria',
#        'Blood Glucose Random', 'Blood Urea', 'Serum Creatinine', 'Sodium',
#        'Potassium', 'Hemoglobin', 'Packed Cell Volume',
#        'White Blood Cell Count', 'Red Blood Cell Count', 'Hypertension',
#        'Diabetes Mellitus', 'Coronary Artery Disease', 'Appetite',
#        'Pedal Edema', 'Anemia', 'Classification'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Age  Blood Pressure  Specific Gravity     Albumin       Sugar  \
# count  391.000000      388.000000        353.000000  354.000000  351.000000
# mean    51.483376       76.469072          1.017408    1.016949    0.450142
# std     17.169714       13.683637          0.005717    1.352679    1.099191
# min      2.000000       50.000000          1.005000    0.000000    0.000000
# 25%     42.000000       70.000000          1.010000    0.000000    0.000000
# 50%     55.000000       80.000000          1.020000    0.000000    0.000000
# 75%     64.500000       80.000000          1.020000    2.000000    0.000000
# max     90.000000      180.000000          1.025000    5.000000    5.000000
#
#        Blood Glucose Random  Blood Urea  Serum Creatinine      Sodium  \
# count            356.000000  381.000000        383.000000  313.000000
# mean             148.036517   57.425722          3.072454  137.528754
# std               79.281714   50.503006          5.741126   10.408752
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      391 non-null    float64
#  1   Blood Pressure           388 non-null    float64
#  2   Specific Gravity         353 non-null    float64
#  3   Albumin                  354 non-null    float64
#  4   Sugar                    351 non-null    float64
#  5   Red Blood Cells          248 non-null    object
#  6   Pus Cells                335 non-null    object
#  7   Pus Cell Clumps          396 non-null    object
#  8   Bacteria                 396 non-null    object
#  9   Blood Glucose Random     356 non-null    float64
#  10  Blood Urea               381 non-null    float64
#  11  Serum Creatinine         383 non-null    float64
#  12  Sodium                   313 non-null    float64
#  13  Potassium                312 non-null    float64
# ...

# %%
df.dtypes
# Out:
# Age                        float64
# Blood Pressure             float64
# Specific Gravity           float64
# Albumin                    float64
# Sugar                      float64
# Red Blood Cells             object
# Pus Cells                   object
# Pus Cell Clumps             object
# Bacteria                    object
# Blood Glucose Random       float64
# Blood Urea                 float64
# Serum Creatinine           float64
# Sodium                     float64
# Potassium                  float64
# Hemoglobin                 float64
# Packed Cell Volume          object
# White Blood Cell Count      object
# Red Blood Cell Count        object
# Hypertension                object
# Diabetes Mellitus           object
# Coronary Artery Disease     object
# Appetite                    object
# Pedal Edema                 object
# Anemia                      object
# Classification              object
# dtype: object

# %%
df['Packed Cell Volume'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
df['Packed Cell Volume']=pd.to_numeric(df['Packed Cell Volume'], errors ='coerce')

# %%
df.dtypes
# Out:
# Age                        float64
# Blood Pressure             float64
# Specific Gravity           float64
# Albumin                    float64
# Sugar                      float64
# Red Blood Cells             object
# Pus Cells                   object
# Pus Cell Clumps             object
# Bacteria                    object
# Blood Glucose Random       float64
# Blood Urea                 float64
# Serum Creatinine           float64
# Sodium                     float64
# Potassium                  float64
# Hemoglobin                 float64
# Packed Cell Volume         float64
# White Blood Cell Count      object
# Red Blood Cell Count        object
# Hypertension                object
# Diabetes Mellitus           object
# Coronary Artery Disease     object
# Appetite                    object
# Pedal Edema                 object
# Anemia                      object
# Classification              object
# dtype: object

# %%
df['White Blood Cell Count'] = pd.to_numeric(df['White Blood Cell Count'], errors ='coerce')
df['Red Blood Cell Count'] = pd.to_numeric(df['Red Blood Cell Count'], errors ='coerce')

# %%
df.dtypes
# Out:
# Age                        float64
# Blood Pressure             float64
# Specific Gravity           float64
# Albumin                    float64
# Sugar                      float64
# Red Blood Cells             object
# Pus Cells                   object
# Pus Cell Clumps             object
# Bacteria                    object
# Blood Glucose Random       float64
# Blood Urea                 float64
# Serum Creatinine           float64
# Sodium                     float64
# Potassium                  float64
# Hemoglobin                 float64
# Packed Cell Volume         float64
# White Blood Cell Count     float64
# Red Blood Cell Count       float64
# Hypertension                object
# Diabetes Mellitus           object
# Coronary Artery Disease     object
# Appetite                    object
# Pedal Edema                 object
# Anemia                      object
# Classification              object
# dtype: object

# %%
df['Packed Cell Volume'].unique()
# Out:
# array([44., 38., 31., 32., 35., 39., 36., 33., 29., 28., nan, 16., 24.,
#        37., 30., 34., 40., 45., 27., 48., 52., 14., 22., 18., 42., 17.,
#        46., 23., 19., 25., 41., 26., 15., 21., 43., 20., 47.,  9., 49.,
#        50., 53., 51., 54.])

# %%
cat_cols = list(df.dtypes[df.dtypes=='object'].index)
num_cols = list(df.dtypes[df.dtypes!='object'].index)

# %%
cat_cols
# Out:
# ['Red Blood Cells',
#  'Pus Cells',
#  'Pus Cell Clumps',
#  'Bacteria',
#  'Hypertension',
#  'Diabetes Mellitus',
#  'Coronary Artery Disease',
#  'Appetite',
#  'Pedal Edema',
#  'Anemia',
#  'Classification']

# %%
num_cols
# Out:
# ['Age',
#  'Blood Pressure',
#  'Specific Gravity',
#  'Albumin',
#  'Sugar',
#  'Blood Glucose Random',
#  'Blood Urea',
#  'Serum Creatinine',
#  'Sodium',
#  'Potassium',
#  'Hemoglobin',
#  'Packed Cell Volume',
#  'White Blood Cell Count',
#  'Red Blood Cell Count']

# %%
#unique Values in cat colums

for col in cat_cols:
  print(f"the {col} has the unique colums{df[col].unique()}")
# Out:
# the Red Blood Cells has the unique colums[nan 'normal' 'abnormal']
# the Pus Cells has the unique colums['normal' 'abnormal' nan]
# the Pus Cell Clumps has the unique colums['notpresent' 'present' nan]
# the Bacteria has the unique colums['notpresent' 'present' nan]
# the Hypertension has the unique colums['yes' 'no' nan]
# the Diabetes Mellitus has the unique colums['yes' 'no' ' yes' '\tno' '\tyes' nan]
# the Coronary Artery Disease has the unique colums['no' 'yes' '\tno' nan]
# the Appetite has the unique colums['good' 'poor' nan]
# the Pedal Edema has the unique colums['no' 'yes' nan]
# the Anemia has the unique colums['no' 'yes' nan]
# the Classification has the unique colums['ckd' 'ckd\t' 'notckd']

# %%
df['Diabetes Mellitus'] = df['Diabetes Mellitus'].replace(to_replace = {' yes':'yes', '\tno':'no','\tyes':'yes'})

# %%
df['Diabetes Mellitus'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df['Coronary Artery Disease'] = df['Coronary Artery Disease'].replace(to_replace = {'\tno':'no'})
df['Classification'] = df['Classification'].replace(to_replace = {'ckd\t':'ckd'})

# %%
df.head(1)
# Out:
#     Age  Blood Pressure  Specific Gravity  Albumin  Sugar Red Blood Cells  \
# 0  48.0            80.0              1.02      1.0    0.0             NaN
#
#   Pus Cells Pus Cell Clumps    Bacteria  Blood Glucose Random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
#
#    Packed Cell Volume  White Blood Cell Count  Red Blood Cell Count  \
# 0                44.0                  7800.0                   5.2
#
#    Hypertension  Diabetes Mellitus  Coronary Artery Disease  Appetite  \
# 0           yes                yes                       no      good
#
#    Pedal Edema Anemia Classification
# 0           no     no            ckd
#
# [1 rows x 25 columns]

# %%
df['Classification'] = df['Classification'].map({'ckd': 0, 'notckd' : 1})

# %%
df['Classification']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    1
# 399    1
# Name: Classification, Length: 400, dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Blood Pressure', 'Specific Gravity', 'Albumin', 'Sugar',
#        'Red Blood Cells', 'Pus Cells', 'Pus Cell Clumps', 'Bacteria',
#        'Blood Glucose Random', 'Blood Urea', 'Serum Creatinine', 'Sodium',
#        'Potassium', 'Hemoglobin', 'Packed Cell Volume',
#        'White Blood Cell Count', 'Red Blood Cell Count', 'Hypertension',
#        'Diabetes Mellitus', 'Coronary Artery Disease', 'Appetite',
#        'Pedal Edema', 'Anemia', 'Classification'],
#       dtype='object')

# %%
#univeriant alalysis

sns.histplot(df['Age'].dropna(), kde = True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# age is left skewed data

# %%
sns.countplot(x = 'Hypertension', data = df, palette= 'viridis')
# Out:
# <Axes: xlabel='Hypertension', ylabel='count'>

# %%
# 150 of them has Hypertension

# %%
sns.boxplot(x = 'Classification', y = 'Blood Urea', data = df, palette = 'viridis')
# Out:
# <Axes: xlabel='Classification', ylabel='Blood Urea'>

# %%
# outliers in the blood urea with respect to classification

# %%
sns.violinplot(x = 'Classification', y = 'Serum Creatinine', data = df, palette = 'muted')
# Out:
# <Axes: xlabel='Classification', ylabel='Serum Creatinine'>

# %%
# the tail is too long that means this has outliar

# %%
sns.countplot(x= 'Anemia', data = df, palette = 'pastel')
# Out:
# <Axes: xlabel='Anemia', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Age', 'Blood Pressure', 'Specific Gravity', 'Albumin', 'Sugar',
#        'Red Blood Cells', 'Pus Cells', 'Pus Cell Clumps', 'Bacteria',
#        'Blood Glucose Random', 'Blood Urea', 'Serum Creatinine', 'Sodium',
#        'Potassium', 'Hemoglobin', 'Packed Cell Volume',
#        'White Blood Cell Count', 'Red Blood Cell Count', 'Hypertension',
#        'Diabetes Mellitus', 'Coronary Artery Disease', 'Appetite',
#        'Pedal Edema', 'Anemia', 'Classification'],
#       dtype='object')

# %%
df['Appetite'].value_counts().plot.pie(autopct = '%1.1f%%', colors= ['lightcoral', 'lightgreen'], explode= (0,0.1), shadow = True, startangle = 90)
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['Age', 'Blood Pressure', 'Specific Gravity', 'Albumin', 'Sugar',
#        'Red Blood Cells', 'Pus Cells', 'Pus Cell Clumps', 'Bacteria',
#        'Blood Glucose Random', 'Blood Urea', 'Serum Creatinine', 'Sodium',
#        'Potassium', 'Hemoglobin', 'Packed Cell Volume',
#        'White Blood Cell Count', 'Red Blood Cell Count', 'Hypertension',
#        'Diabetes Mellitus', 'Coronary Artery Disease', 'Appetite',
#        'Pedal Edema', 'Anemia', 'Classification'],
#       dtype='object')

# %%
sns.countplot(x = 'Pus Cell Clumps', data = df)
# Out:
# <Axes: xlabel='Pus Cell Clumps', ylabel='count'>

# %%
sns.histplot(df['White Blood Cell Count'].dropna(), kde = True, color = 'darkorange')
# Out:
# <Axes: xlabel='White Blood Cell Count', ylabel='Count'>

# %%
# all the above alalysys are univariant analysis

# %%
# bivariate analysis

sns.scatterplot(x = 'Age', y = 'Blood Pressure', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='Blood Pressure'>

# %%
sns.scatterplot(x = 'Age', y = 'Blood Pressure', data = df, hue = 'Classification', palette = 'coolwarm')
# Out:
# <Axes: xlabel='Age', ylabel='Blood Pressure'>

# %%
# as age is increasing BP is also increaseing

# %%
sns.boxplot(x= 'Diabetes Mellitus', y = 'Albumin', data = df)
# Out:
# <Axes: xlabel='Diabetes Mellitus', ylabel='Albumin'>

# %%
#staked bar chart

diabates_hypertension = pd.crosstab(df['Diabetes Mellitus'], df['Hypertension'])

diabates_hypertension.plot(kind= 'bar', stacked= True)
# Out:
# <Axes: xlabel='Diabetes Mellitus'>

# %%
# if there is Diabetes_Meletas there must be Hypertension

# %%
df.columns
# Out:
# Index(['Age', 'Blood Pressure', 'Specific Gravity', 'Albumin', 'Sugar',
#        'Red Blood Cells', 'Pus Cells', 'Pus Cell Clumps', 'Bacteria',
#        'Blood Glucose Random', 'Blood Urea', 'Serum Creatinine', 'Sodium',
#        'Potassium', 'Hemoglobin', 'Packed Cell Volume',
#        'White Blood Cell Count', 'Red Blood Cell Count', 'Hypertension',
#        'Diabetes Mellitus', 'Coronary Artery Disease', 'Appetite',
#        'Pedal Edema', 'Anemia', 'Classification'],
#       dtype='object')

# %%
#multiveriate analysis

col= ['Age', 'Blood Pressure', 'Blood Glucose Random','Serum Creatinine', 'Classification']

sns.pairplot(df[col], hue = 'Classification', palette = 'husl')

# %%
df.corr(numeric_only = True)
# Out:
#                              Age  Blood Pressure  Specific Gravity   Albumin  \
# Age                     1.000000        0.159480         -0.191096  0.122091
# Blood Pressure          0.159480        1.000000         -0.218836  0.160689
# Specific Gravity       -0.191096       -0.218836          1.000000 -0.469760
# Albumin                 0.122091        0.160689         -0.469760  1.000000
# Sugar                   0.220866        0.222576         -0.296234  0.269305
# Blood Glucose Random    0.244992        0.160193         -0.374710  0.379464
# Blood Urea              0.196985        0.188517         -0.314295  0.453528
# Serum Creatinine        0.132531        0.146222         -0.361473  0.399198
# Sodium                 -0.100046       -0.116422          0.412190 -0.459896
# Potassium               0.058377        0.075151         -0.072787  0.129038
# Hemoglobin             -0.192928       -0.306540          0.602582 -0.634632
# ...

# %%
df.dtypes
# Out:
# Age                        float64
# Blood Pressure             float64
# Specific Gravity           float64
# Albumin                    float64
# Sugar                      float64
# Red Blood Cells             object
# Pus Cells                   object
# Pus Cell Clumps             object
# Bacteria                    object
# Blood Glucose Random       float64
# Blood Urea                 float64
# Serum Creatinine           float64
# Sodium                     float64
# Potassium                  float64
# Hemoglobin                 float64
# Packed Cell Volume         float64
# White Blood Cell Count     float64
# Red Blood Cell Count       float64
# Hypertension                object
# Diabetes Mellitus           object
# Coronary Artery Disease     object
# Appetite                    object
# Pedal Edema                 object
# Anemia                      object
# Classification               int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

for col in cat_cols:
  df[col] = LE.fit_transform(df[col])

# %%
df.dtypes
# Out:
# Age                        float64
# Blood Pressure             float64
# Specific Gravity           float64
# Albumin                    float64
# Sugar                      float64
# Red Blood Cells              int64
# Pus Cells                    int64
# Pus Cell Clumps              int64
# Bacteria                     int64
# Blood Glucose Random       float64
# Blood Urea                 float64
# Serum Creatinine           float64
# Sodium                     float64
# Potassium                  float64
# Hemoglobin                 float64
# Packed Cell Volume         float64
# White Blood Cell Count     float64
# Red Blood Cell Count       float64
# Hypertension                 int64
# Diabetes Mellitus            int64
# Coronary Artery Disease      int64
# Appetite                     int64
# Pedal Edema                  int64
# Anemia                       int64
# Classification               int64
# dtype: object
